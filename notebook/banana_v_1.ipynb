# %% [markdown]
# # Klasifikasi Pisang: CNN From Scratch vs MobileNetV2
#
# Notebook Google Colab ini memenuhi tahapan eksperimen berikut:
#
# 1. Mengunduh dataset Kaggle.
# 2. Memeriksa struktur, jumlah gambar, kelas, dan file rusak.
# 3. Membagi data secara **stratified 80% training, 10% validation, dan 10% testing**.
# 4. Melatih **CNN From Scratch** berbasis `Sequential`, `Conv2D`, dan `MaxPooling2D`.
# 5. Melatih **Transfer Learning MobileNetV2** dengan bobot `imagenet`.
# 6. Melakukan **feature extraction** dan **fine-tuning 20 layer terakhir**.
# 7. Menggunakan callback `EarlyStopping`, `ReduceLROnPlateau`, dan `ModelCheckpoint`.
# 8. Menampilkan grafik akurasi/loss, confusion matrix, classification report, serta analisis fit.
# 9. Membandingkan kedua model dan memilih model terbaik.
# 10. Mengekspor model ke **TensorFlow SavedModel**, **TensorFlow Lite**, dan **TensorFlow.js**.
# 11. Menguji inferensi TFLite menggunakan beberapa gambar dari testing set yang tidak digunakan saat training.
#
# > **Saran runtime:** buka `Runtime → Change runtime type → T4 GPU` sebelum menjalankan seluruh sel.

# %% [markdown]
# ## 1. Instalasi dan Import Library
#
# `kagglehub` digunakan untuk mengunduh dataset. Library TensorFlow.js dipasang pada bagian ekspor agar tidak mengganggu versi TensorFlow selama training.

# %%
# !pip install -q -U kagglehub

# %%
import os
import gc
import json
import math
import random
import shutil
import warnings
from pathlib import Path
from concurrent.futures import ThreadPoolExecutor

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image, UnidentifiedImageError

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix,
    ConfusionMatrixDisplay,
)
from sklearn.utils.class_weight import compute_class_weight

import kagglehub

warnings.filterwarnings("ignore")
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

print("TensorFlow :", tf.__version__)
print("GPU       :", tf.config.list_physical_devices("GPU"))
# Out:
# TensorFlow : 2.20.0
# GPU       : [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## 2. Konfigurasi Eksperimen
#
# Nilai epoch dapat dinaikkan apabila akurasi validasi belum mencapai target. Ukuran citra `224 × 224` sesuai input standar MobileNetV2.

# %%
# Reproducibility
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# Dataset split
TRAIN_RATIO = 0.80
VAL_RATIO   = 0.10
TEST_RATIO  = 0.10

# Image pipeline
IMG_HEIGHT = 224
IMG_WIDTH  = 224
IMG_SIZE   = (IMG_HEIGHT, IMG_WIDTH)
BATCH_SIZE = 64
AUTOTUNE   = tf.data.AUTOTUNE

# Training
SCRATCH_EPOCHS       = 30
TL_STAGE1_EPOCHS     = 30
TL_FINETUNE_EPOCHS   = 30
EXTRA_TUNING_EPOCHS  = 20
TARGET_ACCURACY      = 0.90
FINE_TUNE_LAYERS     = 50

# Aktifkan untuk melanjutkan training jika validation accuracy belum 85%
AUTO_TUNE_IF_NEEDED = True

# Output
OUTPUT_DIR = Path("/content/databanana_outputs")
MODEL_DIR  = OUTPUT_DIR / "models"
RESULT_DIR = OUTPUT_DIR / "results"
EXPORT_DIR = OUTPUT_DIR / "exports"

for directory in [OUTPUT_DIR, MODEL_DIR, RESULT_DIR, EXPORT_DIR]:
    directory.mkdir(parents=True, exist_ok=True)

print("Output directory:", OUTPUT_DIR)
# Out:
# Output directory: /content/databanana_outputs

# %% [markdown]
# ## 3. Download Dataset Kaggle

# %%
# The following code will only execute successfully when compression is complete
path = kagglehub.dataset_download("atrithakar/banana-classification")

DATASET_PATH = Path(path)
print("Path to dataset files:", DATASET_PATH)
print("Dataset tersedia:", DATASET_PATH.exists())
# Out:
# Downloading to /root/.cache/kagglehub/datasets/atrithakar/banana-classification/1.archive...
# 100%|██████████| 218M/218M [00:11<00:00, 20.6MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/atrithakar/banana-classification/versions/1
# Dataset tersedia: True

# %% [markdown]
# ## 4. Pemeriksaan Struktur Dataset
#
# Fungsi berikut mencari semua gambar secara rekursif. Label ditentukan dengan aturan:
#
# - Struktur `train/nama_kelas/gambar.jpg` → label adalah `nama_kelas`.
# - Struktur `validation/nama_kelas/gambar.jpg` → label adalah `nama_kelas`.
# - Struktur `dataset/nama_kelas/gambar.jpg` → label adalah nama folder induk gambar.
#
# Split bawaan dataset tidak digunakan sebagai split akhir. Semua data dikumpulkan lalu dibagi ulang secara stratified 80:10:10 untuk menjamin proporsi yang konsisten.

# %%
IMAGE_EXTENSIONS = {".jpg", ".jpeg", ".png", ".bmp", ".webp", ".tif", ".tiff"}

SPLIT_ALIASES = {
    "train": "train",
    "training": "train",
    "val": "validation",
    "valid": "validation",
    "validation": "validation",
    "test": "test",
    "testing": "test",
}

def infer_label_and_original_split(image_path: Path, root: Path):
    relative_parts = list(image_path.relative_to(root).parts)
    lower_parts = [part.lower() for part in relative_parts]

    # Cari pola split/kelas/file
    for index, part in enumerate(lower_parts[:-1]):
        if part in SPLIT_ALIASES and index + 1 < len(relative_parts) - 1:
            label = relative_parts[index + 1]
            return label, SPLIT_ALIASES[part]

    # Default: nama folder induk gambar
    return image_path.parent.name, "raw"

image_paths = sorted([
    file_path
    for file_path in DATASET_PATH.rglob("*")
    if file_path.is_file() and file_path.suffix.lower() in IMAGE_EXTENSIONS
])

if not image_paths:
    raise FileNotFoundError(
        f"Tidak ditemukan file gambar di {DATASET_PATH}. "
        "Periksa hasil download atau struktur dataset."
    )

records = []
for image_path in image_paths:
    label, original_split = infer_label_and_original_split(image_path, DATASET_PATH)
    records.append({
        "filepath": str(image_path),
        "label": str(label).strip(),
        "original_split": original_split,
    })

df = pd.DataFrame(records)
print(f"Jumlah file gambar awal: {len(df):,}")
print(f"Jumlah label terdeteksi : {df['label'].nunique()}")
display(df.head())
# Out:
# Jumlah file gambar awal: 13,478
# Jumlah label terdeteksi : 4
#                                             filepath     label original_split
# 0  /root/.cache/kagglehub/datasets/atrithakar/ban...  overripe           test
# 1  /root/.cache/kagglehub/datasets/atrithakar/ban...  overripe           test
# 2  /root/.cache/kagglehub/datasets/atrithakar/ban...  overripe           test
# 3  /root/.cache/kagglehub/datasets/atrithakar/ban...  overripe           test
# 4  /root/.cache/kagglehub/datasets/atrithakar/ban...  overripe           test

# %%
# Tampilkan struktur direktori secara ringkas
def print_tree(root: Path, max_depth=3, max_items_per_dir=8):
    root = Path(root)
    print(root.name + "/")

    def walk(directory, prefix="", depth=0):
        if depth >= max_depth:
            return

        try:
            items = sorted(directory.iterdir(), key=lambda p: (p.is_file(), p.name.lower()))
        except PermissionError:
            return

        shown = items[:max_items_per_dir]
        for i, item in enumerate(shown):
            connector = "└── " if i == len(shown) - 1 else "├── "
            print(prefix + connector + item.name + ("/" if item.is_dir() else ""))
            if item.is_dir():
                extension = "    " if i == len(shown) - 1 else "│   "
                walk(item, prefix + extension, depth + 1)

        if len(items) > max_items_per_dir:
            print(prefix + f"└── ... ({len(items) - max_items_per_dir} item lain)")

    walk(root)

print_tree(DATASET_PATH)
# Out:
# 1/
# └── banana_classification/
#     ├── test/
#     │   ├── overripe/
#     │   ├── ripe/
#     │   ├── rotten/
#     │   └── unripe/
#     ├── train/
#     │   ├── overripe/
#     │   ├── ripe/
#     │   ├── rotten/
#     │   └── unripe/
#     ├── valid/
#     │   ├── overripe/
#     │   ├── ripe/
#     │   ├── rotten/
#     │   └── unripe/
#     ├── README.dataset.txt
#     └── README.roboflow.txt

# %% [markdown]
# ## 5. Validasi File Gambar dan Distribusi Kelas
#
# File gambar yang tidak dapat dibaca akan dikeluarkan. Pemeriksaan ini mencegah proses training berhenti karena file rusak.

# %%
def verify_image(filepath):
    try:
        with Image.open(filepath) as image:
            image.verify()
        return True
    except (UnidentifiedImageError, OSError, ValueError):
        return False

print("Memeriksa integritas gambar...")

with ThreadPoolExecutor(max_workers=min(32, (os.cpu_count() or 4) * 2)) as executor:
    valid_flags = list(executor.map(verify_image, df["filepath"].tolist()))

df["is_valid"] = valid_flags

invalid_df = df[~df["is_valid"]].copy()
df = df[df["is_valid"]].drop(columns="is_valid").reset_index(drop=True)

print(f"Gambar valid : {len(df):,}")
print(f"Gambar rusak : {len(invalid_df):,}")

if len(invalid_df) > 0:
    display(invalid_df.head())
    invalid_df.to_csv(RESULT_DIR / "invalid_images.csv", index=False)
# Out:
# Memeriksa integritas gambar...
# Gambar valid : 13,478
# Gambar rusak : 0

# %%
# Hapus label kosong dan kelas yang terlalu kecil untuk stratified split
df = df[df["label"].astype(str).str.len() > 0].copy()

MIN_IMAGES_PER_CLASS = 20
class_counts = df["label"].value_counts()
small_classes = class_counts[class_counts < MIN_IMAGES_PER_CLASS]

if len(small_classes) > 0:
    print("Kelas berikut dikeluarkan karena jumlah gambar kurang dari",
          MIN_IMAGES_PER_CLASS)
    display(small_classes.rename("jumlah_gambar").to_frame())
    df = df[~df["label"].isin(small_classes.index)].reset_index(drop=True)

class_counts = df["label"].value_counts().sort_index()
num_classes = len(class_counts)
total_images = len(df)

print(f"Total gambar siap pakai : {total_images:,}")
print(f"Jumlah kelas            : {num_classes}")

if num_classes < 4:
    raise ValueError(
        f"Hanya terdeteksi {num_classes} kelas. Tugas mewajibkan minimal 4 kelas. "
        "Periksa struktur folder atau fungsi inferensi label."
    )

if total_images < 8_000:
    print(
        f"⚠️ PERINGATAN: total gambar hanya {total_images:,}, "
        "sedangkan ketentuan tugas minimal 8.000 gambar."
    )
else:
    print("✅ Ketentuan minimal 8.000 gambar terpenuhi.")

display(class_counts.rename("jumlah_gambar").to_frame())
# Out:
# Total gambar siap pakai : 13,478
# Jumlah kelas            : 4
# ✅ Ketentuan minimal 8.000 gambar terpenuhi.
#           jumlah_gambar
# label
# overripe           2691
# ripe               4015
# rotten             4593
# unripe             2179

# %%
plt.figure(figsize=(12, max(5, num_classes * 0.35)))
class_counts.sort_values().plot(kind="barh")
plt.title("Distribusi Jumlah Gambar per Kelas")
plt.xlabel("Jumlah Gambar")
plt.ylabel("Kelas")
plt.tight_layout()
plt.savefig(RESULT_DIR / "distribusi_kelas.png", dpi=150, bbox_inches="tight")
plt.show()

# %% [markdown]
# ## 6. Stratified Split 80:10:10
#
# `stratify` menjaga proporsi setiap kelas tetap hampir sama pada training, validation, dan testing.

# %%
class_names = sorted(df["label"].unique().tolist())
class_to_index = {class_name: index for index, class_name in enumerate(class_names)}
index_to_class = {index: class_name for class_name, index in class_to_index.items()}

df["label_id"] = df["label"].map(class_to_index).astype("int32")

# 80% train, 20% temporary
train_df, temp_df = train_test_split(
    df,
    test_size=(VAL_RATIO + TEST_RATIO),
    random_state=SEED,
    stratify=df["label"],
)

# Temporary 20% dibagi menjadi 10% validation dan 10% testing
relative_test_ratio = TEST_RATIO / (VAL_RATIO + TEST_RATIO)

val_df, test_df = train_test_split(
    temp_df,
    test_size=relative_test_ratio,
    random_state=SEED,
    stratify=temp_df["label"],
)

train_df = train_df.reset_index(drop=True)
val_df   = val_df.reset_index(drop=True)
test_df  = test_df.reset_index(drop=True)

print(f"Training   : {len(train_df):,} ({len(train_df)/len(df):.2%})")
print(f"Validation : {len(val_df):,} ({len(val_df)/len(df):.2%})")
print(f"Testing    : {len(test_df):,} ({len(test_df)/len(df):.2%})")

assert set(train_df["filepath"]).isdisjoint(set(val_df["filepath"]))
assert set(train_df["filepath"]).isdisjoint(set(test_df["filepath"]))
assert set(val_df["filepath"]).isdisjoint(set(test_df["filepath"]))

train_df.assign(split="train").to_csv(RESULT_DIR / "train_split.csv", index=False)
val_df.assign(split="validation").to_csv(RESULT_DIR / "validation_split.csv", index=False)
test_df.assign(split="test").to_csv(RESULT_DIR / "test_split.csv", index=False)

with open(RESULT_DIR / "class_names.json", "w", encoding="utf-8") as file:
    json.dump(class_names, file, ensure_ascii=False, indent=2)

split_distribution = pd.concat([
    train_df["label"].value_counts().rename("train"),
    val_df["label"].value_counts().rename("validation"),
    test_df["label"].value_counts().rename("test"),
], axis=1).fillna(0).astype(int).sort_index()

display(split_distribution)
# Out:
# Training   : 10,782 (80.00%)
# Validation : 1,348 (10.00%)
# Testing    : 1,348 (10.00%)
#           train  validation  test
# label
# overripe   2153         269   269
# ripe       3212         401   402
# rotten     3674         460   459
# unripe     1743         218   218

# %% [markdown]
# ## 7. Membuat Pipeline `tf.data`
#
# Resize dilakukan melalui kode, sehingga resolusi gambar asli boleh tidak seragam. Data augmentation ditempatkan di dalam model dan hanya aktif saat training.

# %%
def load_and_resize_image(filepath, label):
    image_bytes = tf.io.read_file(filepath)
    image = tf.io.decode_image(
        image_bytes,
        channels=3,
        expand_animations=False
    )
    image.set_shape([None, None, 3])
    image = tf.image.resize(
        image,
        IMG_SIZE,
        method="bilinear",
        antialias=True
    )
    image = tf.cast(image, tf.float32)
    return image, label

def make_dataset(dataframe, training=False):
    dataset = tf.data.Dataset.from_tensor_slices(
        (
            dataframe["filepath"].astype(str).values,
            dataframe["label_id"].astype("int32").values,
        )
    )

    options = tf.data.Options()
    options.experimental_deterministic = not training
    dataset = dataset.with_options(options)

    if training:
        dataset = dataset.shuffle(
            buffer_size=min(len(dataframe), 10_000),
            seed=SEED,
            reshuffle_each_iteration=True,
        )

    dataset = dataset.map(
        load_and_resize_image,
        num_parallel_calls=AUTOTUNE,
    )
    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.prefetch(AUTOTUNE)
    return dataset

train_ds = make_dataset(train_df, training=True)
val_ds   = make_dataset(val_df, training=False)
test_ds  = make_dataset(test_df, training=False)

print("Train element spec:", train_ds.element_spec)
# Out:
# Train element spec: (TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))

# %%
# Bobot kelas membantu apabila distribusi dataset tidak seimbang
classes_array = np.array(sorted(train_df["label_id"].unique()))

weights = compute_class_weight(
    class_weight="balanced",
    classes=classes_array,
    y=train_df["label_id"].values,
)

class_weight = {
    int(class_id): float(weight)
    for class_id, weight in zip(classes_array, weights)
}

print("Class weight:")
for class_id, weight in class_weight.items():
    print(f"{class_names[class_id]:25s}: {weight:.4f}")
# Out:
# Class weight:
# overripe                 : 1.2520
# ripe                     : 0.8392
# rotten                   : 0.7337
# unripe                   : 1.5465

# %%
# Visualisasi sampel training
images, labels = next(iter(train_ds))

plt.figure(figsize=(12, 10))
for index in range(min(12, len(images))):
    plt.subplot(3, 4, index + 1)
    plt.imshow(tf.cast(images[index], tf.uint8))
    plt.title(class_names[int(labels[index])])
    plt.axis("off")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 8. Data Augmentation
#
# Augmentasi meningkatkan variasi data training dan membantu mengurangi overfitting. Transformasi dibuat moderat agar karakter objek sampah tidak berubah secara berlebihan.

# %%
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.20),
        layers.RandomZoom(0.20),
        layers.RandomTranslation(height_factor=0.08, width_factor=0.08),
        layers.RandomContrast(0.20),
        layers.RandomBrightness(0.15),
        layers.RandomContrast(0.15)
    ],
    name="data_augmentation",
)

# %% [markdown]
# ## 9. Fungsi Callback
#
# - **EarlyStopping:** menghentikan training ketika `val_loss` tidak membaik dan mengembalikan bobot terbaik.
# - **ReduceLROnPlateau:** menurunkan learning rate ketika model stagnan.
# - **ModelCheckpoint:** menyimpan model dengan `val_accuracy` terbaik.

# %%
def create_callbacks(model_name):
    checkpoint_path = MODEL_DIR / f"{model_name}_best.keras"

    callbacks = [
        keras.callbacks.EarlyStopping(
            monitor="val_loss",
            patience=7,
            restore_best_weights=True,
            verbose=1,
        ),
        keras.callbacks.ReduceLROnPlateau(
            monitor="val_loss",
            factor=0.3,
            patience=3,
            min_lr=1e-6,
            verbose=1,
        ),
        keras.callbacks.ModelCheckpoint(
            filepath=str(checkpoint_path),
            monitor="val_accuracy",
            mode="max",
            save_best_only=True,
            verbose=1,
        ),
    ]

    return callbacks, checkpoint_path

# %% [markdown]
# # Model 1 — CNN From Scratch
#
# Arsitektur dibuat menggunakan `Sequential`, beberapa blok `Conv2D + BatchNormalization + MaxPooling2D`, `GlobalAveragePooling2D`, `Dense`, dan `Dropout`.

# %%
tf.keras.backend.clear_session()

model_scratch = keras.Sequential(
    [
        layers.Input(shape=(IMG_HEIGHT, IMG_WIDTH, 3)),
        data_augmentation,
        layers.Rescaling(1.0 / 255),

        layers.Conv2D(32, 3, padding="same", use_bias=False),
        layers.BatchNormalization(),
        layers.Activation("relu"),
        layers.MaxPooling2D(),
        layers.Dropout(0.1),

        layers.Conv2D(64, 3, padding="same", use_bias=False),
        layers.BatchNormalization(),
        layers.Activation("relu"),
        layers.MaxPooling2D(),


        layers.Conv2D(128, 3, padding="same", use_bias=False),
        layers.BatchNormalization(),
        layers.Activation("relu"),
        layers.MaxPooling2D(),
        layers.Dropout(0.25),

        layers.Conv2D(256, 3, padding="same", use_bias=False),
        layers.BatchNormalization(),
        layers.Activation("relu"),
        layers.MaxPooling2D(),


        layers.Conv2D(384, 3, padding="same", use_bias=False),
        layers.BatchNormalization(),
        layers.Activation("relu"),
        layers.MaxPooling2D(),
        layers.Dropout(0.35),

        layers.Conv2D(512, 3, padding="same", use_bias=False),
        layers.BatchNormalization(),
        layers.Activation("relu"),
        layers.MaxPooling2D(),
        layers.Dropout(0.4),

        layers.GlobalAveragePooling2D(),
        layers.Dense(256, activation="relu"),
        layers.BatchNormalization(),
        layers.Dropout(0.5),
        layers.Dense(num_classes, activation="softmax", dtype="float32"),
    ],
    name="cnn_from_scratch",
)

model_scratch.compile(
    optimizer=keras.optimizers.AdamW(learning_rate=1e-3),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)

model_scratch.summary()
# Out:
# Model: "cnn_from_scratch"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ data_augmentation (Sequential)  │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling (Rescaling)           │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 224, 224, 32)   │           864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 224, 224, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 224, 224, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 112, 112, 64)   │        18,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 112, 112, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 56, 56, 128)    │        73,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 56, 56, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 28, 28, 256)    │       294,912 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 28, 28, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 14, 14, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 14, 14, 384)    │       884,736 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 14, 14, 384)    │         1,536 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 14, 14, 384)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 7, 7, 384)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 7, 7, 384)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 7, 7, 512)      │     1,769,472 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 7, 7, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 7, 7, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 3, 3, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 3, 3, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │         1,028 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,181,028 (12.13 MB)
#  Trainable params: 3,177,764 (12.12 MB)
#  Non-trainable params: 3,264 (12.75 KB)

# %%
scratch_callbacks, scratch_checkpoint = create_callbacks("cnn_scratch")

history_scratch = model_scratch.fit(
    train_ds,
    validation_data=val_ds,
    epochs=SCRATCH_EPOCHS,
    callbacks=scratch_callbacks,
    class_weight=class_weight,
)
# Out:
# Epoch 1/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.7087 - loss: 0.8080
# Epoch 1: val_accuracy improved from None to 0.30415, saving model to /content/databanana_outputs/models/cnn_scratch_best.keras
#
# Epoch 1: finished saving model to /content/databanana_outputs/models/cnn_scratch_best.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 76s 361ms/step - accuracy: 0.7867 - loss: 0.5631 - val_accuracy: 0.3042 - val_loss: 1.8615 - learning_rate: 0.0010
# Epoch 2/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.8580 - loss: 0.3489
# Epoch 2: val_accuracy improved from 0.30415 to 0.56306, saving model to /content/databanana_outputs/models/cnn_scratch_best.keras
#
# Epoch 2: finished saving model to /content/databanana_outputs/models/cnn_scratch_best.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 62s 365ms/step - accuracy: 0.8646 - loss: 0.3387 - val_accuracy: 0.5631 - val_loss: 0.9776 - learning_rate: 0.0010
# Epoch 3/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.8879 - loss: 0.2867
# Epoch 3: val_accuracy improved from 0.56306 to 0.86128, saving model to /content/databanana_outputs/models/cnn_scratch_best.keras
#
# Epoch 3: finished saving model to /content/databanana_outputs/models/cnn_scratch_best.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 61s 357ms/step - accuracy: 0.8899 - loss: 0.2841 - val_accuracy: 0.8613 - val_loss: 0.3742 - learning_rate: 0.0010
# Epoch 4/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.8971 - loss: 0.2632
# Epoch 4: val_accuracy improved from 0.86128 to 0.89169, saving model to /content/databanana_outputs/models/cnn_scratch_best.keras
#
# Epoch 4: finished saving model to /content/databanana_outputs/models/cnn_scratch_best.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 83s 363ms/step - accuracy: 0.9036 - loss: 0.2534 - val_accuracy: 0.8917 - val_loss: 0.3012 - learning_rate: 0.0010
# Epoch 5/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.9045 - loss: 0.2483
# Epoch 5: val_accuracy did not improve from 0.89169
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 62s 365ms/step - accuracy: 0.9090 - loss: 0.2403 - val_accuracy: 0.8286 - val_loss: 0.4952 - learning_rate: 0.0010
# Epoch 6/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.9130 - loss: 0.2243
# Epoch 6: val_accuracy improved from 0.89169 to 0.91469, saving model to /content/databanana_outputs/models/cnn_scratch_best.keras
#
# Epoch 6: finished saving model to /content/databanana_outputs/models/cnn_scratch_best.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 62s 363ms/step - accuracy: 0.9177 - loss: 0.2178 - val_accuracy: 0.9147 - val_loss: 0.2369 - learning_rate: 0.0010
# Epoch 7/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 0.9247 - loss: 0.1982
# Epoch 7: val_accuracy did not improve from 0.91469
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 62s 365ms/step - accuracy: 0.9251 - loss: 0.1991 - val_accuracy: 0.9125 - val_loss: 0.2503 - learning_rate: 0.0010
# Epoch 8/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.9221 - loss: 0.2048
# Epoch 8: val_accuracy improved from 0.91469 to 0.92062, saving model to /content/databanana_outputs/models/cnn_scratch_best.keras
#
# Epoch 8: finished saving model to /content/databanana_outputs/models/cnn_scratch_best.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 62s 367ms/step - accuracy: 0.9244 - loss: 0.2021 - val_accuracy: 0.9206 - val_loss: 0.1996 - learning_rate: 0.0010
# Epoch 9/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.9261 - loss: 0.1904
# Epoch 9: val_accuracy did not improve from 0.92062
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 62s 365ms/step - accuracy: 0.9276 - loss: 0.1936 - val_accuracy: 0.8175 - val_loss: 0.4958 - learning_rate: 0.0010
# Epoch 10/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 0.9167 - loss: 0.2137
# Epoch 10: val_accuracy improved from 0.92062 to 0.94139, saving model to /content/databanana_outputs/models/cnn_scratch_best.keras
#
# Epoch 10: finished saving model to /content/databanana_outputs/models/cnn_scratch_best.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 63s 368ms/step - accuracy: 0.9268 - loss: 0.1876 - val_accuracy: 0.9414 - val_loss: 0.1903 - learning_rate: 0.0010
# Epoch 11/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - accuracy: 0.9330 - loss: 0.1832
# Epoch 11: val_accuracy did not improve from 0.94139
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 81s 363ms/step - accuracy: 0.9341 - loss: 0.1776 - val_accuracy: 0.9125 - val_loss: 0.2543 - learning_rate: 0.0010
# Epoch 12/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.9388 - loss: 0.1632
# Epoch 12: val_accuracy did not improve from 0.94139
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 62s 365ms/step - accuracy: 0.9397 - loss: 0.1648 - val_accuracy: 0.7478 - val_loss: 0.8049 - learning_rate: 0.0010
# Epoch 13/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - accuracy: 0.9432 - loss: 0.1612
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
#
# Epoch 13: val_accuracy did not improve from 0.94139
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 82s 368ms/step - accuracy: 0.9430 - loss: 0.1626 - val_accuracy: 0.8858 - val_loss: 0.3314 - learning_rate: 0.0010
# Epoch 14/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 0.9517 - loss: 0.1328
# Epoch 14: val_accuracy improved from 0.94139 to 0.94659, saving model to /content/databanana_outputs/models/cnn_scratch_best.keras
#
# Epoch 14: finished saving model to /content/databanana_outputs/models/cnn_scratch_best.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 62s 367ms/step - accuracy: 0.9518 - loss: 0.1314 - val_accuracy: 0.9466 - val_loss: 0.1547 - learning_rate: 3.0000e-04
# Epoch 15/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.9511 - loss: 0.1289
# Epoch 15: val_accuracy improved from 0.94659 to 0.95697, saving model to /content/databanana_outputs/models/cnn_scratch_best.keras
#
# Epoch 15: finished saving model to /content/databanana_outputs/models/cnn_scratch_best.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 62s 363ms/step - accuracy: 0.9547 - loss: 0.1239 - val_accuracy: 0.9570 - val_loss: 0.1302 - learning_rate: 3.0000e-04
# Epoch 16/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.9572 - loss: 0.1143
# Epoch 16: val_accuracy did not improve from 0.95697
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 62s 365ms/step - accuracy: 0.9572 - loss: 0.1159 - val_accuracy: 0.9540 - val_loss: 0.1499 - learning_rate: 3.0000e-04
# Epoch 17/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.9581 - loss: 0.1103
# Epoch 17: val_accuracy did not improve from 0.95697
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 62s 365ms/step - accuracy: 0.9565 - loss: 0.1172 - val_accuracy: 0.9214 - val_loss: 0.2096 - learning_rate: 3.0000e-04
# Epoch 18/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.9616 - loss: 0.1095
# Epoch 18: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
#
# Epoch 18: val_accuracy did not improve from 0.95697
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 62s 365ms/step - accuracy: 0.9608 - loss: 0.1114 - val_accuracy: 0.9525 - val_loss: 0.1480 - learning_rate: 3.0000e-04
# Epoch 19/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 0.9610 - loss: 0.1091
# Epoch 19: val_accuracy improved from 0.95697 to 0.96958, saving model to /content/databanana_outputs/models/cnn_scratch_best.keras
#
# Epoch 19: finished saving model to /content/databanana_outputs/models/cnn_scratch_best.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 61s 360ms/step - accuracy: 0.9619 - loss: 0.1048 - val_accuracy: 0.9696 - val_loss: 0.0894 - learning_rate: 9.0000e-05
# Epoch 20/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - accuracy: 0.9666 - loss: 0.0970
# Epoch 20: val_accuracy improved from 0.96958 to 0.97033, saving model to /content/databanana_outputs/models/cnn_scratch_best.keras
#
# Epoch 20: finished saving model to /content/databanana_outputs/models/cnn_scratch_best.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 62s 368ms/step - accuracy: 0.9655 - loss: 0.0955 - val_accuracy: 0.9703 - val_loss: 0.0864 - learning_rate: 9.0000e-05
# Epoch 21/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 0.9676 - loss: 0.0880
# Epoch 21: val_accuracy improved from 0.97033 to 0.97478, saving model to /content/databanana_outputs/models/cnn_scratch_best.keras
#
# Epoch 21: finished saving model to /content/databanana_outputs/models/cnn_scratch_best.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 61s 361ms/step - accuracy: 0.9676 - loss: 0.0916 - val_accuracy: 0.9748 - val_loss: 0.0686 - learning_rate: 9.0000e-05
# Epoch 22/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - accuracy: 0.9648 - loss: 0.0915
# Epoch 22: val_accuracy did not improve from 0.97478
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 62s 367ms/step - accuracy: 0.9666 - loss: 0.0936 - val_accuracy: 0.9644 - val_loss: 0.1091 - learning_rate: 9.0000e-05
# Epoch 23/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 0.9652 - loss: 0.0927
# Epoch 23: val_accuracy did not improve from 0.97478
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 62s 364ms/step - accuracy: 0.9667 - loss: 0.0914 - val_accuracy: 0.9748 - val_loss: 0.0756 - learning_rate: 9.0000e-05
# Epoch 24/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 0.9709 - loss: 0.0825
# Epoch 24: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
#
# Epoch 24: val_accuracy did not improve from 0.97478
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 61s 359ms/step - accuracy: 0.9708 - loss: 0.0865 - val_accuracy: 0.9688 - val_loss: 0.0879 - learning_rate: 9.0000e-05
# Epoch 25/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - accuracy: 0.9727 - loss: 0.0786
# Epoch 25: val_accuracy did not improve from 0.97478
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 61s 360ms/step - accuracy: 0.9730 - loss: 0.0772 - val_accuracy: 0.9733 - val_loss: 0.0921 - learning_rate: 2.7000e-05
# Epoch 26/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 0.9733 - loss: 0.0758
# Epoch 26: val_accuracy did not improve from 0.97478
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 61s 361ms/step - accuracy: 0.9733 - loss: 0.0747 - val_accuracy: 0.9733 - val_loss: 0.0828 - learning_rate: 2.7000e-05
# Epoch 27/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 0.9722 - loss: 0.0781
# Epoch 27: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
#
# Epoch 27: val_accuracy improved from 0.97478 to 0.97626, saving model to /content/databanana_outputs/models/cnn_scratch_best.keras
#
# Epoch 27: finished saving model to /content/databanana_outputs/models/cnn_scratch_best.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 62s 367ms/step - accuracy: 0.9723 - loss: 0.0799 - val_accuracy: 0.9763 - val_loss: 0.0747 - learning_rate: 2.7000e-05
# Epoch 28/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - accuracy: 0.9696 - loss: 0.0795
# Epoch 28: val_accuracy did not improve from 0.97626
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 62s 366ms/step - accuracy: 0.9722 - loss: 0.0778 - val_accuracy: 0.9733 - val_loss: 0.0727 - learning_rate: 8.1000e-06
# Epoch 28: early stopping
# Restoring model weights from the end of the best epoch: 21.

# %% [markdown]
# ### Tuning Otomatis CNN
#
# Testing set **tidak digunakan** untuk mengambil keputusan tuning. Apabila akurasi validasi terbaik belum 85%, training dilanjutkan menggunakan learning rate yang lebih kecil.

# %%
def merge_histories(*histories):
    merged = {}
    for history in histories:
        if history is None:
            continue
        for key, values in history.history.items():
            merged.setdefault(key, []).extend(values)
    return merged

extra_history_scratch = None
best_scratch_val = max(history_scratch.history.get("val_accuracy", [0]))

if AUTO_TUNE_IF_NEEDED and best_scratch_val < TARGET_ACCURACY:
    print(
        f"Validation accuracy terbaik CNN baru {best_scratch_val:.2%}. "
        "Melanjutkan tuning dengan learning rate 1e-4..."
    )

    model_scratch.compile(
        optimizer=keras.optimizers.Adam(learning_rate=1e-4),
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"],
    )

    scratch_tune_callbacks, _ = create_callbacks("cnn_scratch_tuned")

    extra_history_scratch = model_scratch.fit(
        train_ds,
        validation_data=val_ds,
        epochs=EXTRA_TUNING_EPOCHS,
        callbacks=scratch_tune_callbacks,
        class_weight=class_weight,
    )
else:
    print(f"Validation accuracy CNN terbaik: {best_scratch_val:.2%}")

scratch_history_all = merge_histories(history_scratch, extra_history_scratch)
# Out:
# Validation accuracy CNN terbaik: 97.63%

# %% [markdown]
# ## 10. Fungsi Visualisasi dan Evaluasi

# %%
def plot_training_history(history_dict, model_name, save_prefix):
    epochs = range(1, len(history_dict["accuracy"]) + 1)

    plt.figure(figsize=(9, 5))
    plt.plot(epochs, history_dict["accuracy"], label="Training Accuracy")
    plt.plot(epochs, history_dict["val_accuracy"], label="Validation Accuracy")
    plt.title(f"{model_name} — Accuracy")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.grid(alpha=0.3)
    plt.tight_layout()
    plt.savefig(RESULT_DIR / f"{save_prefix}_accuracy.png", dpi=150)
    plt.show()

    plt.figure(figsize=(9, 5))
    plt.plot(epochs, history_dict["loss"], label="Training Loss")
    plt.plot(epochs, history_dict["val_loss"], label="Validation Loss")
    plt.title(f"{model_name} — Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(alpha=0.3)
    plt.tight_layout()
    plt.savefig(RESULT_DIR / f"{save_prefix}_loss.png", dpi=150)
    plt.show()

def collect_predictions(model, dataset):
    y_true = []
    y_probability = []

    for batch_images, batch_labels in dataset:
        probabilities = model.predict(batch_images, verbose=0)
        y_probability.append(probabilities)
        y_true.append(batch_labels.numpy())

    y_true = np.concatenate(y_true)
    y_probability = np.concatenate(y_probability)
    y_pred = np.argmax(y_probability, axis=1)
    return y_true, y_pred, y_probability

def diagnose_fit(history_dict, train_accuracy, test_accuracy):
    final_train_acc = history_dict["accuracy"][-1]
    final_val_acc = history_dict["val_accuracy"][-1]
    best_val_acc = max(history_dict["val_accuracy"])
    gap = train_accuracy - test_accuracy

    if train_accuracy < 0.80 and best_val_acc < 0.80:
        diagnosis = "UNDERFITTING"
        explanation = (
            "Akurasi training dan validation masih rendah. Model belum mampu "
            "mempelajari pola data secara memadai."
        )
    elif gap > 0.08 or (final_train_acc - final_val_acc) > 0.10:
        diagnosis = "OVERFITTING"
        explanation = (
            "Akurasi training jauh lebih tinggi daripada validation/testing. "
            "Model terlalu menyesuaikan diri terhadap data training."
        )
    else:
        diagnosis = "GOOD FIT"
        explanation = (
            "Selisih performa training dan testing relatif kecil, sehingga "
            "kemampuan generalisasi model cukup baik."
        )

    return diagnosis, explanation

def evaluate_complete(model, model_name, history_dict, prefix):
    print("=" * 80)
    print(model_name)
    print("=" * 80)

    train_loss, train_accuracy = model.evaluate(train_ds, verbose=0)
    val_loss, val_accuracy = model.evaluate(val_ds, verbose=0)
    test_loss, test_accuracy = model.evaluate(test_ds, verbose=0)

    print(f"Training   accuracy: {train_accuracy:.4f} | loss: {train_loss:.4f}")
    print(f"Validation accuracy: {val_accuracy:.4f} | loss: {val_loss:.4f}")
    print(f"Testing    accuracy: {test_accuracy:.4f} | loss: {test_loss:.4f}")

    plot_training_history(history_dict, model_name, prefix)

    y_true, y_pred, y_probability = collect_predictions(model, test_ds)

    report_dict = classification_report(
        y_true,
        y_pred,
        labels=list(range(num_classes)),
        target_names=class_names,
        output_dict=True,
        zero_division=0,
    )
    report_df = pd.DataFrame(report_dict).transpose()
    report_df.to_csv(RESULT_DIR / f"{prefix}_classification_report.csv")
    display(report_df.round(4))

    matrix = confusion_matrix(
        y_true,
        y_pred,
        labels=list(range(num_classes)),
    )

    figure_size = max(8, min(20, num_classes * 0.8))
    fig, ax = plt.subplots(figsize=(figure_size, figure_size))
    display_matrix = ConfusionMatrixDisplay(
        confusion_matrix=matrix,
        display_labels=class_names,
    )
    display_matrix.plot(
        ax=ax,
        cmap="Blues",
        xticks_rotation=45,
        values_format="d",
        colorbar=False,
    )
    plt.title(f"{model_name} — Confusion Matrix")
    plt.tight_layout()
    plt.savefig(
        RESULT_DIR / f"{prefix}_confusion_matrix.png",
        dpi=150,
        bbox_inches="tight",
    )
    plt.show()

    diagnosis, explanation = diagnose_fit(
        history_dict,
        train_accuracy,
        test_accuracy,
    )

    print(f"Analisis fit: {diagnosis}")
    print(explanation)

    if train_accuracy >= TARGET_ACCURACY and test_accuracy >= TARGET_ACCURACY:
        print("✅ Target training dan testing accuracy minimal 85% tercapai.")
    else:
        print(
            "⚠️ Target 85% belum tercapai pada salah satu metrik. "
            "Pertimbangkan menambah epoch, menyesuaikan augmentasi, "
            "learning rate, atau kapasitas model."
        )

    result = {
        "model": model_name,
        "train_loss": train_loss,
        "train_accuracy": train_accuracy,
        "val_loss": val_loss,
        "val_accuracy": val_accuracy,
        "test_loss": test_loss,
        "test_accuracy": test_accuracy,
        "fit_status": diagnosis,
    }

    return result, y_true, y_pred, y_probability

# %%
scratch_result, scratch_y_true, scratch_y_pred, scratch_y_probability = evaluate_complete(
    model_scratch,
    model_name="CNN From Scratch",
    history_dict=scratch_history_all,
    prefix="cnn_scratch",
)
# Out:
# ================================================================================
# CNN From Scratch
# ================================================================================
# Training   accuracy: 0.9752 | loss: 0.0725
# Validation accuracy: 0.9748 | loss: 0.0686
# Testing    accuracy: 0.9726 | loss: 0.0813
#               precision  recall  f1-score    support
# overripe         0.9848  0.9665    0.9756   269.0000
# ripe             0.9566  0.9876    0.9718   402.0000
# rotten           0.9756  0.9564    0.9659   459.0000
# unripe           0.9817  0.9862    0.9840   218.0000
# accuracy         0.9726  0.9726    0.9726     0.9726
# macro avg        0.9747  0.9742    0.9743  1348.0000
# weighted avg     0.9728  0.9726    0.9725  1348.0000
# Analisis fit: GOOD FIT
# Selisih performa training dan testing relatif kecil, sehingga kemampuan generalisasi model cukup baik.
# ✅ Target training dan testing accuracy minimal 85% tercapai.

# %% [markdown]
# # Model 2 — Transfer Learning MobileNetV2
#
# ## Tahap 1: Feature Extraction
#
# Seluruh layer MobileNetV2 dibekukan (`trainable = False`). Classification head baru terdiri dari `GlobalAveragePooling2D → Dense → Dropout → Output`.

# %%
# Data augmentation dibuat ulang agar tidak berbagi state model sebelumnya
tl_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.08),
        layers.RandomZoom(0.10),
        layers.RandomTranslation(height_factor=0.08, width_factor=0.08),
        layers.RandomContrast(0.10),
    ],
    name="tl_data_augmentation",
)

base_model = tf.keras.applications.MobileNetV2(
    input_shape=(IMG_HEIGHT, IMG_WIDTH, 3),
    include_top=False,
    weights="imagenet",
)

# Strategi wajib tahap 1: freeze seluruh convolutional base
base_model.trainable = False

inputs = keras.Input(shape=(IMG_HEIGHT, IMG_WIDTH, 3), name="input_image")
x = tl_augmentation(inputs)
x = layers.Rescaling(1.0 / 127.5, offset=-1.0, name="mobilenet_preprocessing")(x)
x = base_model(x, training=False)
x = layers.GlobalAveragePooling2D(name="global_average_pooling")(x)
x = layers.Dense(256, activation="relu", name="classification_dense")(x)
x = layers.BatchNormalization(name="classification_batch_norm")(x)
x = layers.Dropout(0.40, name="classification_dropout")(x)
outputs = layers.Dense(
    num_classes,
    activation="softmax",
    dtype="float32",
    name="predictions",
)(x)

model_tl = keras.Model(inputs, outputs, name="mobilenetv2_transfer_learning")

model_tl.compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-3),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)

print("Base model trainable:", base_model.trainable)
print("Jumlah layer base model:", len(base_model.layers))
model_tl.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Base model trainable: False
# Jumlah layer base model: 154
# Model: "mobilenetv2_transfer_learning"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_image (InputLayer)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ tl_data_augmentation            │ (None, 224, 224, 3)    │             0 │
# │ (Sequential)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenet_preprocessing         │ (None, 224, 224, 3)    │             0 │
# │ (Rescaling)                     │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenetv2_1.00_224            │ (None, 7, 7, 1280)     │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling          │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ classification_dense (Dense)    │ (None, 256)            │       327,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ classification_batch_norm       │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ classification_dropout          │ (None, 256)            │             0 │
# │ (Dropout)                       │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ predictions (Dense)             │ (None, 4)              │         1,028 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,587,972 (9.87 MB)
#  Trainable params: 329,476 (1.26 MB)
#  Non-trainable params: 2,258,496 (8.62 MB)

# %%
tl_stage1_callbacks, tl_stage1_checkpoint = create_callbacks(
    "mobilenetv2_feature_extraction"
)

history_tl_stage1 = model_tl.fit(
    train_ds,
    validation_data=val_ds,
    epochs=TL_STAGE1_EPOCHS,
    callbacks=tl_stage1_callbacks,
    class_weight=class_weight,
)
# Out:
# Epoch 1/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.8445 - loss: 0.4143
# Epoch 1: val_accuracy improved from None to 0.94659, saving model to /content/databanana_outputs/models/mobilenetv2_feature_extraction_best.keras
#
# Epoch 1: finished saving model to /content/databanana_outputs/models/mobilenetv2_feature_extraction_best.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 51s 255ms/step - accuracy: 0.9048 - loss: 0.2593 - val_accuracy: 0.9466 - val_loss: 0.1577 - learning_rate: 0.0010
# Epoch 2/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.9458 - loss: 0.1475
# Epoch 2: val_accuracy improved from 0.94659 to 0.95401, saving model to /content/databanana_outputs/models/mobilenetv2_feature_extraction_best.keras
#
# Epoch 2: finished saving model to /content/databanana_outputs/models/mobilenetv2_feature_extraction_best.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 42s 247ms/step - accuracy: 0.9463 - loss: 0.1437 - val_accuracy: 0.9540 - val_loss: 0.1552 - learning_rate: 0.0010
# Epoch 3/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 0.9486 - loss: 0.1338
# Epoch 3: val_accuracy improved from 0.95401 to 0.96884, saving model to /content/databanana_outputs/models/mobilenetv2_feature_extraction_best.keras
#
# Epoch 3: finished saving model to /content/databanana_outputs/models/mobilenetv2_feature_extraction_best.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 42s 248ms/step - accuracy: 0.9496 - loss: 0.1298 - val_accuracy: 0.9688 - val_loss: 0.0961 - learning_rate: 0.0010
# Epoch 4/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.9577 - loss: 0.1167
# Epoch 4: val_accuracy did not improve from 0.96884
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 40s 238ms/step - accuracy: 0.9559 - loss: 0.1164 - val_accuracy: 0.9503 - val_loss: 0.1364 - learning_rate: 0.0010
# Epoch 5/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 0.9646 - loss: 0.0980
# Epoch 5: val_accuracy did not improve from 0.96884
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 40s 238ms/step - accuracy: 0.9648 - loss: 0.0951 - val_accuracy: 0.9599 - val_loss: 0.1234 - learning_rate: 0.0010
# Epoch 6/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 0.9613 - loss: 0.1020
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
#
# Epoch 6: val_accuracy did not improve from 0.96884
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 42s 244ms/step - accuracy: 0.9647 - loss: 0.0941 - val_accuracy: 0.9644 - val_loss: 0.1053 - learning_rate: 0.0010
# Epoch 7/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 0.9684 - loss: 0.0785
# Epoch 7: val_accuracy did not improve from 0.96884
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 41s 240ms/step - accuracy: 0.9671 - loss: 0.0854 - val_accuracy: 0.9688 - val_loss: 0.0885 - learning_rate: 3.0000e-04
# Epoch 8/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 0.9705 - loss: 0.0799
# Epoch 8: val_accuracy improved from 0.96884 to 0.97404, saving model to /content/databanana_outputs/models/mobilenetv2_feature_extraction_best.keras
#
# Epoch 8: finished saving model to /content/databanana_outputs/models/mobilenetv2_feature_extraction_best.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 42s 246ms/step - accuracy: 0.9699 - loss: 0.0791 - val_accuracy: 0.9740 - val_loss: 0.0832 - learning_rate: 3.0000e-04
# Epoch 9/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9714 - loss: 0.0789
# Epoch 9: val_accuracy improved from 0.97404 to 0.97478, saving model to /content/databanana_outputs/models/mobilenetv2_feature_extraction_best.keras
#
# Epoch 9: finished saving model to /content/databanana_outputs/models/mobilenetv2_feature_extraction_best.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 41s 241ms/step - accuracy: 0.9741 - loss: 0.0737 - val_accuracy: 0.9748 - val_loss: 0.0789 - learning_rate: 3.0000e-04
# Epoch 10/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 0.9714 - loss: 0.0756
# Epoch 10: val_accuracy did not improve from 0.97478
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 42s 246ms/step - accuracy: 0.9732 - loss: 0.0751 - val_accuracy: 0.9748 - val_loss: 0.0790 - learning_rate: 3.0000e-04
# Epoch 11/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 0.9751 - loss: 0.0728
# Epoch 11: val_accuracy improved from 0.97478 to 0.97552, saving model to /content/databanana_outputs/models/mobilenetv2_feature_extraction_best.keras
#
# Epoch 11: finished saving model to /content/databanana_outputs/models/mobilenetv2_feature_extraction_best.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 41s 242ms/step - accuracy: 0.9733 - loss: 0.0725 - val_accuracy: 0.9755 - val_loss: 0.0777 - learning_rate: 3.0000e-04
# Epoch 12/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 0.9755 - loss: 0.0591
# Epoch 12: val_accuracy did not improve from 0.97552
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 42s 245ms/step - accuracy: 0.9759 - loss: 0.0625 - val_accuracy: 0.9755 - val_loss: 0.0796 - learning_rate: 3.0000e-04
# Epoch 13/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.9712 - loss: 0.0702
# Epoch 13: val_accuracy improved from 0.97552 to 0.97923, saving model to /content/databanana_outputs/models/mobilenetv2_feature_extraction_best.keras
#
# Epoch 13: finished saving model to /content/databanana_outputs/models/mobilenetv2_feature_extraction_best.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 46s 269ms/step - accuracy: 0.9736 - loss: 0.0686 - val_accuracy: 0.9792 - val_loss: 0.0709 - learning_rate: 3.0000e-04
# Epoch 14/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 0.9759 - loss: 0.0632
# Epoch 14: val_accuracy did not improve from 0.97923
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 42s 245ms/step - accuracy: 0.9753 - loss: 0.0640 - val_accuracy: 0.9777 - val_loss: 0.0768 - learning_rate: 3.0000e-04
# Epoch 15/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.9781 - loss: 0.0591
# Epoch 15: val_accuracy did not improve from 0.97923
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 46s 271ms/step - accuracy: 0.9783 - loss: 0.0607 - val_accuracy: 0.9755 - val_loss: 0.0763 - learning_rate: 3.0000e-04
# Epoch 16/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.9792 - loss: 0.0545
# Epoch 16: val_accuracy improved from 0.97923 to 0.98071, saving model to /content/databanana_outputs/models/mobilenetv2_feature_extraction_best.keras
#
# Epoch 16: finished saving model to /content/databanana_outputs/models/mobilenetv2_feature_extraction_best.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 42s 247ms/step - accuracy: 0.9768 - loss: 0.0597 - val_accuracy: 0.9807 - val_loss: 0.0635 - learning_rate: 3.0000e-04
# Epoch 17/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.9770 - loss: 0.0575
# Epoch 17: val_accuracy did not improve from 0.98071
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 41s 242ms/step - accuracy: 0.9761 - loss: 0.0624 - val_accuracy: 0.9785 - val_loss: 0.0722 - learning_rate: 3.0000e-04
# Epoch 18/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.9781 - loss: 0.0592
# Epoch 18: val_accuracy did not improve from 0.98071
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 81s 237ms/step - accuracy: 0.9784 - loss: 0.0593 - val_accuracy: 0.9763 - val_loss: 0.0740 - learning_rate: 3.0000e-04
# Epoch 19/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.9795 - loss: 0.0522
# Epoch 19: val_accuracy improved from 0.98071 to 0.98145, saving model to /content/databanana_outputs/models/mobilenetv2_feature_extraction_best.keras
#
# Epoch 19: finished saving model to /content/databanana_outputs/models/mobilenetv2_feature_extraction_best.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 41s 240ms/step - accuracy: 0.9795 - loss: 0.0563 - val_accuracy: 0.9815 - val_loss: 0.0595 - learning_rate: 3.0000e-04
# Epoch 20/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 0.9796 - loss: 0.0540
# Epoch 20: val_accuracy did not improve from 0.98145
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 46s 272ms/step - accuracy: 0.9786 - loss: 0.0555 - val_accuracy: 0.9666 - val_loss: 0.0905 - learning_rate: 3.0000e-04
# Epoch 21/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.9787 - loss: 0.0547
# Epoch 21: val_accuracy did not improve from 0.98145
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 40s 237ms/step - accuracy: 0.9806 - loss: 0.0525 - val_accuracy: 0.9800 - val_loss: 0.0644 - learning_rate: 3.0000e-04
# Epoch 22/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 0.9798 - loss: 0.0553
# Epoch 22: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
#
# Epoch 22: val_accuracy improved from 0.98145 to 0.98220, saving model to /content/databanana_outputs/models/mobilenetv2_feature_extraction_best.keras
#
# Epoch 22: finished saving model to /content/databanana_outputs/models/mobilenetv2_feature_extraction_best.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 42s 248ms/step - accuracy: 0.9791 - loss: 0.0534 - val_accuracy: 0.9822 - val_loss: 0.0663 - learning_rate: 3.0000e-04
# Epoch 23/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9825 - loss: 0.0513
# Epoch 23: val_accuracy improved from 0.98220 to 0.98294, saving model to /content/databanana_outputs/models/mobilenetv2_feature_extraction_best.keras
#
# Epoch 23: finished saving model to /content/databanana_outputs/models/mobilenetv2_feature_extraction_best.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 41s 240ms/step - accuracy: 0.9822 - loss: 0.0488 - val_accuracy: 0.9829 - val_loss: 0.0640 - learning_rate: 9.0000e-05
# Epoch 24/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 0.9818 - loss: 0.0497
# Epoch 24: val_accuracy did not improve from 0.98294
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 41s 242ms/step - accuracy: 0.9818 - loss: 0.0484 - val_accuracy: 0.9800 - val_loss: 0.0638 - learning_rate: 9.0000e-05
# Epoch 25/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 0.9794 - loss: 0.0568
# Epoch 25: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
#
# Epoch 25: val_accuracy did not improve from 0.98294
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 40s 237ms/step - accuracy: 0.9814 - loss: 0.0506 - val_accuracy: 0.9807 - val_loss: 0.0638 - learning_rate: 9.0000e-05
# Epoch 26/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.9849 - loss: 0.0446
# Epoch 26: val_accuracy did not improve from 0.98294
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 41s 244ms/step - accuracy: 0.9835 - loss: 0.0461 - val_accuracy: 0.9800 - val_loss: 0.0617 - learning_rate: 2.7000e-05
# Epoch 26: early stopping
# Restoring model weights from the end of the best epoch: 19.

# %% [markdown]
# ## Tahap 2: Fine-Tuning
#
# Sebanyak 20 layer terakhir dibuka. Layer `BatchNormalization` tetap dibekukan untuk menjaga statistik pretrained tetap stabil. Learning rate diturunkan jauh lebih kecil menjadi `1e-5`.

# %%
base_model.trainable = True

# Bekukan semua layer selain FINE_TUNE_LAYERS terakhir
for layer in base_model.layers[:-FINE_TUNE_LAYERS]:
    layer.trainable = False

# BatchNormalization tetap dibekukan agar fine-tuning lebih stabil
for layer in base_model.layers[-FINE_TUNE_LAYERS:]:
    if isinstance(layer, layers.BatchNormalization):
        layer.trainable = False

trainable_base_layers = sum(layer.trainable for layer in base_model.layers)

print(f"Layer base model yang trainable: {trainable_base_layers}")
print(f"Target maksimum layer terakhir : {FINE_TUNE_LAYERS}")

model_tl.compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-5),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)

tl_finetune_callbacks, tl_finetune_checkpoint = create_callbacks(
    "mobilenetv2_finetuned"
)

history_tl_finetune = model_tl.fit(
    train_ds,
    validation_data=val_ds,
    epochs=TL_FINETUNE_EPOCHS,
    callbacks=tl_finetune_callbacks,
    class_weight=class_weight,
)
# Out:
# Layer base model yang trainable: 33
# Target maksimum layer terakhir : 50
# Epoch 1/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 0.9748 - loss: 0.0613
# Epoch 1: val_accuracy improved from None to 0.96439, saving model to /content/databanana_outputs/models/mobilenetv2_finetuned_best.keras
#
# Epoch 1: finished saving model to /content/databanana_outputs/models/mobilenetv2_finetuned_best.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 52s 256ms/step - accuracy: 0.9783 - loss: 0.0560 - val_accuracy: 0.9644 - val_loss: 0.1043 - learning_rate: 1.0000e-05
# Epoch 2/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 0.9816 - loss: 0.0512
# Epoch 2: val_accuracy improved from 0.96439 to 0.98442, saving model to /content/databanana_outputs/models/mobilenetv2_finetuned_best.keras
#
# Epoch 2: finished saving model to /content/databanana_outputs/models/mobilenetv2_finetuned_best.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 42s 249ms/step - accuracy: 0.9816 - loss: 0.0486 - val_accuracy: 0.9844 - val_loss: 0.0537 - learning_rate: 1.0000e-05
# Epoch 3/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 0.9841 - loss: 0.0413
# Epoch 3: val_accuracy did not improve from 0.98442
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 42s 247ms/step - accuracy: 0.9831 - loss: 0.0463 - val_accuracy: 0.9837 - val_loss: 0.0519 - learning_rate: 1.0000e-05
# Epoch 4/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 0.9854 - loss: 0.0372
# Epoch 4: val_accuracy did not improve from 0.98442
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 41s 242ms/step - accuracy: 0.9846 - loss: 0.0399 - val_accuracy: 0.9800 - val_loss: 0.0519 - learning_rate: 1.0000e-05
# Epoch 5/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 0.9842 - loss: 0.0406
# Epoch 5: val_accuracy did not improve from 0.98442
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 42s 246ms/step - accuracy: 0.9858 - loss: 0.0396 - val_accuracy: 0.9844 - val_loss: 0.0528 - learning_rate: 1.0000e-05
# Epoch 6/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.9891 - loss: 0.0273
# Epoch 6: val_accuracy did not improve from 0.98442
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 41s 242ms/step - accuracy: 0.9890 - loss: 0.0293 - val_accuracy: 0.9837 - val_loss: 0.0469 - learning_rate: 1.0000e-05
# Epoch 7/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 0.9894 - loss: 0.0258
# Epoch 7: val_accuracy did not improve from 0.98442
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 83s 248ms/step - accuracy: 0.9891 - loss: 0.0277 - val_accuracy: 0.9770 - val_loss: 0.0667 - learning_rate: 1.0000e-05
# Epoch 8/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 0.9892 - loss: 0.0274
# Epoch 8: val_accuracy improved from 0.98442 to 0.98739, saving model to /content/databanana_outputs/models/mobilenetv2_finetuned_best.keras
#
# Epoch 8: finished saving model to /content/databanana_outputs/models/mobilenetv2_finetuned_best.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 42s 246ms/step - accuracy: 0.9894 - loss: 0.0274 - val_accuracy: 0.9874 - val_loss: 0.0456 - learning_rate: 1.0000e-05
# Epoch 9/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 0.9898 - loss: 0.0260
# Epoch 9: val_accuracy did not improve from 0.98739
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 41s 240ms/step - accuracy: 0.9903 - loss: 0.0279 - val_accuracy: 0.9815 - val_loss: 0.0541 - learning_rate: 1.0000e-05
# Epoch 10/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 0.9890 - loss: 0.0292
# Epoch 10: val_accuracy did not improve from 0.98739
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 41s 241ms/step - accuracy: 0.9899 - loss: 0.0284 - val_accuracy: 0.9866 - val_loss: 0.0360 - learning_rate: 1.0000e-05
# Epoch 11/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 0.9922 - loss: 0.0220
# Epoch 11: val_accuracy did not improve from 0.98739
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 41s 241ms/step - accuracy: 0.9907 - loss: 0.0266 - val_accuracy: 0.9837 - val_loss: 0.0530 - learning_rate: 1.0000e-05
# Epoch 12/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 0.9905 - loss: 0.0255
# Epoch 12: val_accuracy did not improve from 0.98739
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 42s 246ms/step - accuracy: 0.9910 - loss: 0.0239 - val_accuracy: 0.9837 - val_loss: 0.0555 - learning_rate: 1.0000e-05
# Epoch 13/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 0.9914 - loss: 0.0257
# Epoch 13: val_accuracy improved from 0.98739 to 0.98961, saving model to /content/databanana_outputs/models/mobilenetv2_finetuned_best.keras
#
# Epoch 13: finished saving model to /content/databanana_outputs/models/mobilenetv2_finetuned_best.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 41s 245ms/step - accuracy: 0.9915 - loss: 0.0252 - val_accuracy: 0.9896 - val_loss: 0.0355 - learning_rate: 1.0000e-05
# Epoch 14/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 0.9936 - loss: 0.0174
# Epoch 14: val_accuracy did not improve from 0.98961
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 42s 247ms/step - accuracy: 0.9931 - loss: 0.0202 - val_accuracy: 0.9822 - val_loss: 0.0534 - learning_rate: 1.0000e-05
# Epoch 15/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 0.9918 - loss: 0.0211
# Epoch 15: val_accuracy did not improve from 0.98961
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 41s 241ms/step - accuracy: 0.9921 - loss: 0.0219 - val_accuracy: 0.9881 - val_loss: 0.0408 - learning_rate: 1.0000e-05
# Epoch 16/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 0.9916 - loss: 0.0215
# Epoch 16: ReduceLROnPlateau reducing learning rate to 2.9999999242136253e-06.
#
# Epoch 16: val_accuracy did not improve from 0.98961
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 42s 246ms/step - accuracy: 0.9929 - loss: 0.0195 - val_accuracy: 0.9889 - val_loss: 0.0475 - learning_rate: 1.0000e-05
# Epoch 17/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.9932 - loss: 0.0184
# Epoch 17: val_accuracy did not improve from 0.98961
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 41s 245ms/step - accuracy: 0.9938 - loss: 0.0176 - val_accuracy: 0.9889 - val_loss: 0.0327 - learning_rate: 3.0000e-06
# Epoch 18/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 0.9957 - loss: 0.0162
# Epoch 18: val_accuracy did not improve from 0.98961
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 41s 241ms/step - accuracy: 0.9951 - loss: 0.0162 - val_accuracy: 0.9896 - val_loss: 0.0309 - learning_rate: 3.0000e-06
# Epoch 19/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 0.9941 - loss: 0.0153
# Epoch 19: val_accuracy did not improve from 0.98961
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 41s 242ms/step - accuracy: 0.9938 - loss: 0.0164 - val_accuracy: 0.9896 - val_loss: 0.0320 - learning_rate: 3.0000e-06
# Epoch 20/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 0.9941 - loss: 0.0156
# Epoch 20: val_accuracy improved from 0.98961 to 0.99110, saving model to /content/databanana_outputs/models/mobilenetv2_finetuned_best.keras
#
# Epoch 20: finished saving model to /content/databanana_outputs/models/mobilenetv2_finetuned_best.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 43s 252ms/step - accuracy: 0.9947 - loss: 0.0150 - val_accuracy: 0.9911 - val_loss: 0.0288 - learning_rate: 3.0000e-06
# Epoch 21/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 0.9957 - loss: 0.0128
# Epoch 21: val_accuracy improved from 0.99110 to 0.99184, saving model to /content/databanana_outputs/models/mobilenetv2_finetuned_best.keras
#
# Epoch 21: finished saving model to /content/databanana_outputs/models/mobilenetv2_finetuned_best.keras
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 42s 246ms/step - accuracy: 0.9961 - loss: 0.0126 - val_accuracy: 0.9918 - val_loss: 0.0276 - learning_rate: 3.0000e-06
# Epoch 22/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 0.9960 - loss: 0.0136
# Epoch 22: val_accuracy did not improve from 0.99184
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 41s 241ms/step - accuracy: 0.9955 - loss: 0.0134 - val_accuracy: 0.9896 - val_loss: 0.0299 - learning_rate: 3.0000e-06
# Epoch 23/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 0.9954 - loss: 0.0123
# Epoch 23: val_accuracy did not improve from 0.99184
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 42s 247ms/step - accuracy: 0.9952 - loss: 0.0133 - val_accuracy: 0.9904 - val_loss: 0.0309 - learning_rate: 3.0000e-06
# Epoch 24/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.9958 - loss: 0.0122
# Epoch 24: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 24: val_accuracy did not improve from 0.99184
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 46s 273ms/step - accuracy: 0.9954 - loss: 0.0127 - val_accuracy: 0.9918 - val_loss: 0.0284 - learning_rate: 3.0000e-06
# Epoch 25/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 0.9964 - loss: 0.0125
# Epoch 25: val_accuracy did not improve from 0.99184
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 41s 241ms/step - accuracy: 0.9957 - loss: 0.0124 - val_accuracy: 0.9918 - val_loss: 0.0283 - learning_rate: 1.0000e-06
# Epoch 26/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 0.9962 - loss: 0.0105
# Epoch 26: val_accuracy did not improve from 0.99184
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 42s 248ms/step - accuracy: 0.9960 - loss: 0.0120 - val_accuracy: 0.9911 - val_loss: 0.0281 - learning_rate: 1.0000e-06
# Epoch 27/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 0.9954 - loss: 0.0127
# Epoch 27: val_accuracy did not improve from 0.99184
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 41s 241ms/step - accuracy: 0.9955 - loss: 0.0130 - val_accuracy: 0.9911 - val_loss: 0.0292 - learning_rate: 1.0000e-06
# Epoch 28/30
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 0.9965 - loss: 0.0103
# Epoch 28: val_accuracy did not improve from 0.99184
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 42s 248ms/step - accuracy: 0.9966 - loss: 0.0115 - val_accuracy: 0.9904 - val_loss: 0.0283 - learning_rate: 1.0000e-06
# Epoch 28: early stopping
# Restoring model weights from the end of the best epoch: 21.

# %% [markdown]
# ### Tuning Tambahan MobileNetV2
#
# Apabila validation accuracy belum 85%, fine-tuning dilanjutkan dengan learning rate `3e-6`. Keputusan tetap hanya berdasarkan validation set, bukan testing set.

# %%
tl_history_before_extra = merge_histories(
    history_tl_stage1,
    history_tl_finetune,
)

extra_history_tl = None
best_tl_val = max(tl_history_before_extra.get("val_accuracy", [0]))

if AUTO_TUNE_IF_NEEDED and best_tl_val < TARGET_ACCURACY:
    print(
        f"Validation accuracy terbaik MobileNetV2 baru {best_tl_val:.2%}. "
        "Melanjutkan fine-tuning dengan learning rate 3e-6..."
    )

    model_tl.compile(
        optimizer=keras.optimizers.Adam(learning_rate=3e-6),
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"],
    )

    tl_extra_callbacks, _ = create_callbacks("mobilenetv2_extra_tuned")

    extra_history_tl = model_tl.fit(
        train_ds,
        validation_data=val_ds,
        epochs=EXTRA_TUNING_EPOCHS,
        callbacks=tl_extra_callbacks,
        class_weight=class_weight,
    )
else:
    print(f"Validation accuracy MobileNetV2 terbaik: {best_tl_val:.2%}")

tl_history_all = merge_histories(
    history_tl_stage1,
    history_tl_finetune,
    extra_history_tl,
)
# Out:
# Validation accuracy MobileNetV2 terbaik: 99.18%

# %%
tl_result, tl_y_true, tl_y_pred, tl_y_probability = evaluate_complete(
    model_tl,
    model_name="MobileNetV2 Transfer Learning + Fine-Tuning",
    history_dict=tl_history_all,
    prefix="mobilenetv2",
)
# Out:
# ================================================================================
# MobileNetV2 Transfer Learning + Fine-Tuning
# ================================================================================
# Training   accuracy: 0.9965 | loss: 0.0126
# Validation accuracy: 0.9918 | loss: 0.0276
# Testing    accuracy: 0.9896 | loss: 0.0362
#               precision  recall  f1-score    support
# overripe         0.9926  0.9926    0.9926   269.0000
# ripe             0.9804  0.9975    0.9889   402.0000
# rotten           0.9934  0.9804    0.9868   459.0000
# unripe           0.9954  0.9908    0.9931   218.0000
# accuracy         0.9896  0.9896    0.9896     0.9896
# macro avg        0.9904  0.9903    0.9904  1348.0000
# weighted avg     0.9897  0.9896    0.9896  1348.0000
# Analisis fit: GOOD FIT
# Selisih performa training dan testing relatif kecil, sehingga kemampuan generalisasi model cukup baik.
# ✅ Target training dan testing accuracy minimal 85% tercapai.

# %% [markdown]
# # 11. Perbandingan Kedua Model
#
# Model terbaik dipilih berdasarkan **testing accuracy** setelah seluruh proses training selesai. Testing set hanya digunakan untuk evaluasi final dan tidak digunakan untuk tuning hyperparameter.

# %%
comparison_df = pd.DataFrame([scratch_result, tl_result]).set_index("model")
comparison_df = comparison_df.sort_values("test_accuracy", ascending=False)
display(comparison_df.round(4))

comparison_df.to_csv(RESULT_DIR / "model_comparison.csv")

best_model_name = comparison_df.index[0]

if best_model_name == "CNN From Scratch":
    best_model = model_scratch
    best_result = scratch_result
else:
    best_model = model_tl
    best_result = tl_result

print("Model terbaik:", best_model_name)
print(f"Testing accuracy terbaik: {best_result['test_accuracy']:.2%}")
# Out:
#                                              train_loss  train_accuracy  \
# model
# MobileNetV2 Transfer Learning + Fine-Tuning      0.0126          0.9965
# CNN From Scratch                                 0.0725          0.9752
#
#                                              val_loss  val_accuracy  \
# model
# MobileNetV2 Transfer Learning + Fine-Tuning    0.0276        0.9918
# CNN From Scratch                               0.0686        0.9748
#
#                                              test_loss  test_accuracy  \
# model
# MobileNetV2 Transfer Learning + Fine-Tuning     0.0362         0.9896
# CNN From Scratch                                0.0813         0.9726
#
#                                             fit_status
# model
# MobileNetV2 Transfer Learning + Fine-Tuning   GOOD FIT
# CNN From Scratch                              GOOD FIT
# Model terbaik: MobileNetV2 Transfer Learning + Fine-Tuning
# Testing accuracy terbaik: 98.96%

# %%
# Visualisasi perbandingan akurasi
accuracy_comparison = comparison_df[
    ["train_accuracy", "val_accuracy", "test_accuracy"]
]

ax = accuracy_comparison.plot(kind="bar", figsize=(11, 6))
plt.title("Perbandingan Akurasi Kedua Model")
plt.xlabel("Model")
plt.ylabel("Accuracy")
plt.ylim(0, 1.05)
plt.xticks(rotation=15, ha="right")
plt.grid(axis="y", alpha=0.3)
plt.tight_layout()
plt.savefig(RESULT_DIR / "perbandingan_akurasi_model.png", dpi=150)
plt.show()

# %% [markdown]
# # 12. Penyimpanan Model dalam Tiga Format
#
# Model terbaik diekspor sebagai:
#
# 1. **TensorFlow SavedModel** untuk backend/cloud.
# 2. **TensorFlow Lite (`.tflite`)** untuk mobile atau embedded system.
# 3. **TensorFlow.js** untuk aplikasi berbasis browser.
#
# Selain tiga format wajib, file `.keras`, `.h5`, daftar kelas JSON, dan ringkasan hasil juga disimpan untuk dokumentasi.

# %%
# Simpan model native Keras sebagai cadangan
KERAS_PATH = EXPORT_DIR / "best_datatrash_model.keras"
H5_PATH    = EXPORT_DIR / "best_datatrash_model.h5"

best_model.save(KERAS_PATH)
best_model.save(H5_PATH, include_optimizer=False)

with open(EXPORT_DIR / "class_names.json", "w", encoding="utf-8") as file:
    json.dump(class_names, file, ensure_ascii=False, indent=2)

with open(EXPORT_DIR / "best_model_info.json", "w", encoding="utf-8") as file:
    json.dump(
        {
            "best_model": best_model_name,
            "image_size": [IMG_HEIGHT, IMG_WIDTH],
            "num_classes": num_classes,
            "class_names": class_names,
            "metrics": {
                key: (float(value) if isinstance(value, (np.floating, float)) else value)
                for key, value in best_result.items()
                if key != "model"
            },
        },
        file,
        ensure_ascii=False,
        indent=2,
    )

print("Keras model:", KERAS_PATH)
print("H5 model   :", H5_PATH)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Keras model: /content/databanana_outputs/exports/best_datatrash_model.keras
# H5 model   : /content/databanana_outputs/exports/best_datatrash_model.h5

# %%
# 1) TensorFlow SavedModel
SAVEDMODEL_DIR = EXPORT_DIR / "saved_model"

if SAVEDMODEL_DIR.exists():
    shutil.rmtree(SAVEDMODEL_DIR)

try:
    # Keras 3
    best_model.export(str(SAVEDMODEL_DIR), format="tf_saved_model")
except (AttributeError, TypeError):
    # Fallback untuk versi TensorFlow/Keras lain
    tf.saved_model.save(best_model, str(SAVEDMODEL_DIR))

print("✅ SavedModel tersimpan di:", SAVEDMODEL_DIR)
# Out:
# Saved artifact at '/content/databanana_outputs/exports/saved_model'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_image')
# Output Type:
#   TensorSpec(shape=(None, 4), dtype=tf.float32, name=None)
# Captures:
#   133089371894608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089371894992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089374071376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089371897488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089371891344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089374071760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089374069840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089374073104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089374070992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089374070416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089374073296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089374072144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089374069264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089374073872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089374070800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089374072912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089374074448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089374070224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089374073680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089374071568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089374070608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089374068304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089374071952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089374071184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089374072336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089374067920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089374074640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089374070032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089374072528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089374075600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089374075024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089374074064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089374075408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089374068112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089374076368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089374075216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089374075792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089374076176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089374076752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089374074832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089374073488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089374075984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373077968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089374076560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089374072720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373077776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373078544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373078352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373078160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373079696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373079120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373079312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373079504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373078736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373080656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373080080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373080272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373080464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373077584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373081616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373081040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373081232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373081424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373078928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373082576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373082000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373080848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373082384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373079888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089371894800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373082960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373083344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373083152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373082768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373084496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373083920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373084112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373084304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373081808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373085456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373084880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373085072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373085264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373083536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373086416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373085840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373086032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373086224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373083728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373087376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373086800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373086992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373087184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373084688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373088336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373087760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373087952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373088144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373085648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373089296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373088720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373088912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373089104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373086608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373090256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373089680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373089872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373090064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373087568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373091216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373090640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373090832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373091024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373088528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373092176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373091600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373091792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373091984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373089488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373093136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373092560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373092752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373093328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373093712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373092368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373091408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373092944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361626320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373093520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373090448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361625360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361625744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361625936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361626128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361627280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361626704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361626896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361627088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361625168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361628240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361627664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361627856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361628048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361625552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361629200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361628624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361628816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361629008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361626512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361630160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361629584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361629776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361629968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361627472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361631120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361630544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361630736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361630928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361628432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361632080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361631504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361631696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361631888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361629392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361633040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361632464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361632656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361632848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361630352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361634000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361633424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361633616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361633808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361631312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361634960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361634384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361634576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361634768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361632272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361635920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361635344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361635536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361635728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361633232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361636880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361636304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361636496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361636688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361634192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361637840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361637264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361637456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361637648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361635152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361638800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361638224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361638416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361638608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361636112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361639760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361639184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361639376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361639568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361637072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361640720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361640144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361640336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361640912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361641296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361639952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361638992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361640528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089360790544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361641104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089361638032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089360790736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089360789776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089360789584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089360790160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089360791696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089360791120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089360791312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089360791504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089360790928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089360792656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089360792080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089360792272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089360792464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089360790352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089360793616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089360793040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089360793232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089360793424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089360789968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089360794576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089360794000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089360794192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089360794384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089360791888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089360795536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089360794960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089360795152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089360795344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089360792848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089360796496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089360795920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089360796112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089360796304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089360793808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089360797456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089360796880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089360797072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089360797264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089360794768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089360798416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089360797840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089360798032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089360798224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089360795728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089360799376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089360798800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089360798992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089360799184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089360796688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089360800336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089373082192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089360800528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089360800144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089360800912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089360799568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089360801488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089360802064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133089360801680: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ✅ SavedModel tersimpan di: /content/databanana_outputs/exports/saved_model

# %%
import tensorflow as tf
from tensorflow import keras
import shutil
from pathlib import Path

# Pastikan variabel ini sudah tersedia
print("Image size   :", IMG_HEIGHT, IMG_WIDTH)
print("Jumlah kelas :", num_classes)

# Input baru khusus deployment
export_inputs = keras.Input(
    shape=(IMG_HEIGHT, IMG_WIDTH, 3),
    dtype=tf.float32,
    name="input_image"
)

# Tidak memasukkan tl_augmentation
x = tf.keras.applications.mobilenet_v2.preprocess_input(export_inputs)

# Gunakan MobileNetV2 yang sudah dilatih/fine-tuning
x = base_model(x, training=False)

# Gunakan kembali classification head beserta bobot hasil training
x = model_tl.get_layer("global_average_pooling")(x)
x = model_tl.get_layer("classification_dense")(x)

x = model_tl.get_layer("classification_batch_norm")(
    x,
    training=False
)

x = model_tl.get_layer("classification_dropout")(
    x,
    training=False
)

export_outputs = model_tl.get_layer("predictions")(x)

# Model deployment tanpa augmentasi
inference_model = keras.Model(
    inputs=export_inputs,
    outputs=export_outputs,
    name="mobilenetv2_datatrash_inference"
)

inference_model.summary()
# Out:
# Image size   : 224 224
# Jumlah kelas : 4
# Model: "mobilenetv2_datatrash_inference"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_image (InputLayer)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ true_divide (TrueDivide)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ subtract (Subtract)             │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenetv2_1.00_224            │ (None, 7, 7, 1280)     │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling          │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ classification_dense (Dense)    │ (None, 256)            │       327,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ classification_batch_norm       │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ classification_dropout          │ (None, 256)            │             0 │
# │ (Dropout)                       │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ predictions (Dense)             │ (None, 4)              │         1,028 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,587,972 (9.87 MB)
#  Trainable params: 2,163,908 (8.25 MB)
#  Non-trainable params: 424,064 (1.62 MB)

# %%
sample_images, sample_labels = next(iter(test_ds))

sample_batch = sample_images[:5]

original_predictions = model_tl(
    sample_batch,
    training=False
).numpy()

inference_predictions = inference_model(
    sample_batch,
    training=False
).numpy()

maximum_difference = np.max(
    np.abs(original_predictions - inference_predictions)
)

print("Selisih maksimum prediksi:", maximum_difference)

print(
    "Prediksi model asli     :",
    np.argmax(original_predictions, axis=1)
)

print(
    "Prediksi inference model:",
    np.argmax(inference_predictions, axis=1)
)
# Out:
# Selisih maksimum prediksi: 1.1920929e-07
# Prediksi model asli     : [2 2 3 3 2]
# Prediksi inference model: [2 2 3 3 2]

# %%
CLEAN_SAVEDMODEL_DIR = EXPORT_DIR / "saved_model_inference"

if CLEAN_SAVEDMODEL_DIR.exists():
    shutil.rmtree(CLEAN_SAVEDMODEL_DIR)


@tf.function(
    input_signature=[
        tf.TensorSpec(
            shape=[None, IMG_HEIGHT, IMG_WIDTH, 3],
            dtype=tf.float32,
            name="input_image"
        )
    ]
)
def serving_function(input_image):
    probabilities = inference_model(
        input_image,
        training=False
    )

    return {
        "probabilities": probabilities
    }


tf.saved_model.save(
    inference_model,
    str(CLEAN_SAVEDMODEL_DIR),
    signatures={
        "serving_default": serving_function
    }
)

print("✅ Clean SavedModel tersimpan di:")
print(CLEAN_SAVEDMODEL_DIR)
# Out:
# ✅ Clean SavedModel tersimpan di:
# /content/databanana_outputs/exports/saved_model_inference

# %%
TFLITE_PATH = EXPORT_DIR / "best_datatrash_model.tflite"

converter = tf.lite.TFLiteConverter.from_saved_model(
    str(CLEAN_SAVEDMODEL_DIR)
)

# Dynamic range optimization
converter.optimizations = [
    tf.lite.Optimize.DEFAULT
]

# Hanya izinkan operasi TFLite native
converter.target_spec.supported_ops = [
    tf.lite.OpsSet.TFLITE_BUILTINS
]

try:
    tflite_model = converter.convert()

except Exception as error:
    print("Konversi teroptimasi gagal:")
    print(error)
    print("\nMencoba konversi Float32 standar...")

    converter = tf.lite.TFLiteConverter.from_saved_model(
        str(CLEAN_SAVEDMODEL_DIR)
    )

    converter.target_spec.supported_ops = [
        tf.lite.OpsSet.TFLITE_BUILTINS
    ]

    tflite_model = converter.convert()


TFLITE_PATH.write_bytes(tflite_model)

print("✅ TFLite berhasil disimpan:")
print(TFLITE_PATH)

print(
    f"Ukuran TFLite: "
    f"{TFLITE_PATH.stat().st_size / (1024 ** 2):.2f} MB"
)
# Out:
# ✅ TFLite berhasil disimpan:
# /content/databanana_outputs/exports/best_datatrash_model.tflite
# Ukuran TFLite: 0.21 MB

# %%
interpreter = tf.lite.Interpreter(
    model_path=str(TFLITE_PATH)
)

interpreter.allocate_tensors()

input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

print("Input TFLite:")
print(input_details)

print("\nOutput TFLite:")
print(output_details)
# Out:
# Input TFLite:
# [{'name': 'serving_default_input_image:0', 'index': 0, 'shape': array([  1, 224, 224,   3], dtype=int32), 'shape_signature': array([ -1, 224, 224,   3], dtype=int32), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}]
#
# Output TFLite:
# [{'name': 'StatefulPartitionedCall:0', 'index': 1054, 'shape': array([1, 4], dtype=int32), 'shape_signature': array([-1,  4], dtype=int32), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}]

# %%
# Ambil satu gambar testing
sample_images, sample_labels = next(iter(test_ds))

test_image = sample_images[:1].numpy().astype(
    input_details[0]["dtype"]
)

# Prediksi Keras
keras_prediction = inference_model.predict(
    test_image,
    verbose=0
)

# Prediksi TFLite
interpreter.set_tensor(
    input_details[0]["index"],
    test_image
)

interpreter.invoke()

tflite_prediction = interpreter.get_tensor(
    output_details[0]["index"]
)

keras_class = int(np.argmax(keras_prediction[0]))
tflite_class = int(np.argmax(tflite_prediction[0]))

print("Label asli:")
print(class_names[int(sample_labels[0])])

print("\nPrediksi Keras:")
print(class_names[keras_class])
print("Probabilitas:", float(np.max(keras_prediction[0])))

print("\nPrediksi TFLite:")
print(class_names[tflite_class])
print("Probabilitas:", float(np.max(tflite_prediction[0])))
# Out:
# Label asli:
# rotten
#
# Prediksi Keras:
# rotten
# Probabilitas: 0.9989331364631653
#
# Prediksi TFLite:
# overripe
# Probabilitas: nan

# %% [markdown]
# ### Ekspor TensorFlow.js
#
# Paket TensorFlow.js dipasang **setelah training selesai**. Hal ini mengurangi risiko perubahan dependency selama pelatihan.

# %%
# !pip install -q tensorflowjs
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.1/89.1 kB 8.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.1/16.1 MB 105.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 645.0/645.0 MB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 68.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 121.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 6.7 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigquery-magics 0.14.0 requires packaging>=24.2.0, but you have packaging 23.2 which is incompatible.
# db-dtypes 1.7.0 requires packaging>=24.2.0, but you have packaging 23.2 which is incompatible.
# xarray 2025.12.0 requires packaging>=24.1, but you have packaging 23.2 which is incompatible.
# ydf-tf 2.20.0 requires tensorflow==2.20.0, but you have tensorflow 2.19.0 which is incompatible.
# tensorflow-text 2.20.1 requires tensorflow<2.21,>=2.20.0, but you have tensorflow 2.19.0 which is incompatible.
# google-cloud-bigquery 3.42.1 requires packaging>=24.2.0, but you have packaging 23.2 which is incompatible.

# %%
import shutil
import subprocess
import sys
import os
from pathlib import Path

# Model ini harus model tanpa tl_augmentation
# inference_model dibuat pada bagian perbaikan TFLite sebelumnya

TFJS_H5_PATH = EXPORT_DIR / "datatrash_inference_model.h5"

inference_model.save(
    str(TFJS_H5_PATH),
    include_optimizer=False
)

print("✅ Model inference H5 tersimpan:")
print(TFJS_H5_PATH)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Model inference H5 tersimpan:
# /content/databanana_outputs/exports/datatrash_inference_model.h5

# %%
# 3) TensorFlow.js dari clean inference model

TFJS_DIR = EXPORT_DIR / "tfjs_model"

if TFJS_DIR.exists():
    shutil.rmtree(TFJS_DIR)

TFJS_DIR.mkdir(
    parents=True,
    exist_ok=True
)

converter_executable = shutil.which(
    "tensorflowjs_converter"
)

if converter_executable is None:
    command = [
        sys.executable,
        "-m",
        "tensorflowjs.converters.converter",
        "--input_format=keras",
        "--output_format=tfjs_layers_model",
        str(TFJS_H5_PATH),
        str(TFJS_DIR),
    ]
else:
    command = [
        converter_executable,
        "--input_format=keras",
        "--output_format=tfjs_layers_model",
        str(TFJS_H5_PATH),
        str(TFJS_DIR),
    ]

print("Menjalankan:")
print(" ".join(command))

# Converter tidak membutuhkan GPU.
# Ini juga mengurangi pesan CUDA/cuDNN yang tidak diperlukan.
converter_environment = os.environ.copy()
converter_environment["CUDA_VISIBLE_DEVICES"] = "-1"
converter_environment["TF_CPP_MIN_LOG_LEVEL"] = "2"

result = subprocess.run(
    command,
    capture_output=True,
    text=True,
    env=converter_environment,
)

if result.stdout.strip():
    print("\nOUTPUT:")
    print(result.stdout)

if result.returncode != 0:
    print("\nERROR:")
    print(result.stderr)

    raise RuntimeError(
        "Konversi TensorFlow.js gagal. "
        "Pastikan TFJS_H5_PATH berasal dari inference_model "
        "yang tidak mengandung data augmentation."
    )

model_json = TFJS_DIR / "model.json"

if not model_json.exists():
    raise FileNotFoundError(
        "Konversi selesai, tetapi model.json tidak ditemukan."
    )

tfjs_files = sorted(
    file.name
    for file in TFJS_DIR.iterdir()
)

print("\n✅ TensorFlow.js berhasil disimpan:")
print(TFJS_DIR)

print("\nIsi folder TFJS:")
for filename in tfjs_files:
    print(" -", filename)
# Out:
# Menjalankan:
# /usr/local/bin/tensorflowjs_converter --input_format=keras --output_format=tfjs_layers_model /content/databanana_outputs/exports/datatrash_inference_model.h5 /content/databanana_outputs/exports/tfjs_model
#
# OUTPUT:
# failed to lookup keras version from the file,
#     this is likely a weight only file
#
#
# ✅ TensorFlow.js berhasil disimpan:
# /content/databanana_outputs/exports/tfjs_model
#
# Isi folder TFJS:
#  - group1-shard1of3.bin
#  - group1-shard2of3.bin
#  - group1-shard3of3.bin
#  - model.json

# %%
import json

with open(
    TFJS_DIR / "model.json",
    "r",
    encoding="utf-8"
) as file:
    tfjs_metadata = json.load(file)

print("Format model:")
print(tfjs_metadata.get("format"))

print("\nGenerated by:")
print(tfjs_metadata.get("generatedBy"))

print("\nConverted by:")
print(tfjs_metadata.get("convertedBy"))

print("\nJumlah weight manifest:")
print(len(tfjs_metadata.get("weightsManifest", [])))
# Out:
# Format model:
# layers-model
#
# Generated by:
# keras v3.13.2
#
# Converted by:
# TensorFlow.js Converter v4.22.0
#
# Jumlah weight manifest:
# 1

# %% [markdown]
# # 13. Inferensi Menggunakan TensorFlow Lite
#
# Beberapa gambar diambil dari **testing set**. Gambar tersebut tidak pernah digunakan untuk update bobot selama training, sehingga dapat dipakai sebagai data baru/tidak terlihat oleh model selama proses belajar.

# %%
# Inisialisasi TFLite Interpreter
interpreter = tf.lite.Interpreter(model_path=str(TFLITE_PATH))
interpreter.allocate_tensors()

input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

print("Input details :", input_details)
print("Output details:", output_details)
# Out:
# Input details : [{'name': 'serving_default_input_image:0', 'index': 0, 'shape': array([  1, 224, 224,   3], dtype=int32), 'shape_signature': array([ -1, 224, 224,   3], dtype=int32), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}]
# Output details: [{'name': 'StatefulPartitionedCall:0', 'index': 1054, 'shape': array([1, 4], dtype=int32), 'shape_signature': array([-1,  4], dtype=int32), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0}, 'sparsity_parameters': {}}]

# %%
def prepare_tflite_input(image_path, input_detail):
    with Image.open(image_path) as image:
        image = image.convert("RGB")
        image = image.resize((IMG_WIDTH, IMG_HEIGHT))
        image_array = np.asarray(image, dtype=np.float32)

    image_array = np.expand_dims(image_array, axis=0)
    input_dtype = input_detail["dtype"]

    if input_dtype in (np.uint8, np.int8):
        scale, zero_point = input_detail["quantization"]
        if scale == 0:
            raise ValueError("Skala kuantisasi input bernilai 0.")
        image_array = image_array / scale + zero_point
        image_array = np.clip(
            image_array,
            np.iinfo(input_dtype).min,
            np.iinfo(input_dtype).max,
        ).astype(input_dtype)
    else:
        image_array = image_array.astype(input_dtype)

    return image_array

def predict_tflite(image_path):
    input_tensor = prepare_tflite_input(image_path, input_details[0])

    interpreter.set_tensor(input_details[0]["index"], input_tensor)
    interpreter.invoke()

    output = interpreter.get_tensor(output_details[0]["index"])[0]

    if output_details[0]["dtype"] in (np.uint8, np.int8):
        scale, zero_point = output_details[0]["quantization"]
        output = (output.astype(np.float32) - zero_point) * scale

    predicted_index = int(np.argmax(output))
    probability = float(output[predicted_index])

    return predicted_index, probability, output

# %%
# Ambil beberapa contoh acak dari testing set
NUM_INFERENCE_SAMPLES = min(9, len(test_df))
inference_samples = test_df.sample(
    n=NUM_INFERENCE_SAMPLES,
    random_state=SEED,
).reset_index(drop=True)

inference_records = []

plt.figure(figsize=(15, 12))

for index, row in inference_samples.iterrows():
    predicted_index, probability, probabilities = predict_tflite(row["filepath"])
    predicted_label = class_names[predicted_index]
    actual_label = row["label"]
    is_correct = predicted_label == actual_label

    inference_records.append({
        "filepath": row["filepath"],
        "label_asli": actual_label,
        "hasil_prediksi": predicted_label,
        "probabilitas": probability,
        "benar": is_correct,
    })

    with Image.open(row["filepath"]) as image:
        image = image.convert("RGB")
        plt.subplot(3, 3, index + 1)
        plt.imshow(image)
        plt.title(
            f"Asli: {actual_label}\n"
            f"Prediksi: {predicted_label}\n"
            f"Probabilitas: {probability:.2%}",
            fontsize=10,
        )
        plt.axis("off")

plt.tight_layout()
plt.savefig(
    RESULT_DIR / "tflite_inference_samples.png",
    dpi=150,
    bbox_inches="tight",
)
plt.show()

inference_df = pd.DataFrame(inference_records)
display(inference_df)
inference_df.to_csv(RESULT_DIR / "tflite_inference_results.csv", index=False)
# Out:
#                                             filepath label_asli  \
# 0  /root/.cache/kagglehub/datasets/atrithakar/ban...     rotten
# 1  /root/.cache/kagglehub/datasets/atrithakar/ban...   overripe
# 2  /root/.cache/kagglehub/datasets/atrithakar/ban...     rotten
# 3  /root/.cache/kagglehub/datasets/atrithakar/ban...     unripe
# 4  /root/.cache/kagglehub/datasets/atrithakar/ban...       ripe
# 5  /root/.cache/kagglehub/datasets/atrithakar/ban...     unripe
# 6  /root/.cache/kagglehub/datasets/atrithakar/ban...       ripe
# 7  /root/.cache/kagglehub/datasets/atrithakar/ban...   overripe
# 8  /root/.cache/kagglehub/datasets/atrithakar/ban...       ripe
#
#   hasil_prediksi  probabilitas  benar
# 0       overripe           NaN  False
# 1       overripe           NaN   True
# 2       overripe           NaN  False
# 3       overripe           NaN  False
# 4       overripe           NaN  False
# 5       overripe           NaN  False
# 6       overripe           NaN  False
# 7       overripe           NaN   True
# 8       overripe           NaN  False

# %% [markdown]
# ## 14. Inferensi Opsional dengan Gambar Eksternal
#
# Unggah beberapa gambar yang benar-benar berasal dari luar dataset. Karena notebook tidak mengetahui label aslinya secara otomatis, isi `true_labels` sesuai nama file setelah upload.

# %%
# Jalankan sel ini hanya jika ingin menguji gambar eksternal.
#
# from google.colab import files
# uploaded = files.upload()
#
# Contoh:
# true_labels = {
#     "contoh_1.jpg": "plastic",
#     "contoh_2.jpg": "paper",
# }
#
# external_results = []
#
# for filename in uploaded.keys():
#     predicted_index, probability, _ = predict_tflite(filename)
#     predicted_label = class_names[predicted_index]
#     actual_label = true_labels.get(filename, "BELUM DIISI")
#
#     external_results.append({
#         "filename": filename,
#         "label_asli": actual_label,
#         "hasil_prediksi": predicted_label,
#         "probabilitas": probability,
#     })
#
#     with Image.open(filename) as image:
#         plt.figure(figsize=(5, 5))
#         plt.imshow(image.convert("RGB"))
#         plt.title(
#             f"Asli: {actual_label}\n"
#             f"Prediksi: {predicted_label}\n"
#             f"Probabilitas: {probability:.2%}"
#         )
#         plt.axis("off")
#         plt.show()
#
# display(pd.DataFrame(external_results))

# %% [markdown]
# # 15. Ringkasan Analisis Otomatis
#
# Sel berikut menghasilkan paragraf ringkas yang dapat digunakan sebagai dasar pembahasan hasil. Tetap sesuaikan dengan grafik dan confusion matrix yang diperoleh saat notebook dijalankan.

# %%
scratch_acc = scratch_result["test_accuracy"]
tl_acc = tl_result["test_accuracy"]

if scratch_acc > tl_acc:
    comparison_statement = (
        f"CNN From Scratch menghasilkan testing accuracy lebih tinggi "
        f"({scratch_acc:.2%}) dibandingkan MobileNetV2 ({tl_acc:.2%})."
    )
elif tl_acc > scratch_acc:
    comparison_statement = (
        f"MobileNetV2 menghasilkan testing accuracy lebih tinggi "
        f"({tl_acc:.2%}) dibandingkan CNN From Scratch ({scratch_acc:.2%})."
    )
else:
    comparison_statement = (
        f"Kedua model menghasilkan testing accuracy yang sama, yaitu "
        f"{scratch_acc:.2%}."
    )

analysis_text = f'''
Hasil eksperimen menunjukkan bahwa CNN From Scratch memperoleh training accuracy
{scratch_result["train_accuracy"]:.2%}, validation accuracy
{scratch_result["val_accuracy"]:.2%}, dan testing accuracy
{scratch_result["test_accuracy"]:.2%}. Model ini dikategorikan sebagai
{scratch_result["fit_status"]}.

MobileNetV2 dengan feature extraction dan fine-tuning memperoleh training accuracy
{tl_result["train_accuracy"]:.2%}, validation accuracy
{tl_result["val_accuracy"]:.2%}, dan testing accuracy
{tl_result["test_accuracy"]:.2%}. Model ini dikategorikan sebagai
{tl_result["fit_status"]}.

{comparison_statement} Model terbaik berdasarkan testing accuracy adalah
{best_model_name}. Confusion matrix dan classification report perlu digunakan
untuk mengidentifikasi kelas yang paling mudah dan paling sulit dikenali serta
untuk menilai precision, recall, dan F1-score setiap kelas.
'''.strip()

print(analysis_text)

with open(RESULT_DIR / "ringkasan_analisis.txt", "w", encoding="utf-8") as file:
    file.write(analysis_text)
# Out:
# Hasil eksperimen menunjukkan bahwa CNN From Scratch memperoleh training accuracy
# 97.52%, validation accuracy
# 97.48%, dan testing accuracy
# 97.26%. Model ini dikategorikan sebagai
# GOOD FIT.
#
# MobileNetV2 dengan feature extraction dan fine-tuning memperoleh training accuracy
# 99.65%, validation accuracy
# 99.18%, dan testing accuracy
# 98.96%. Model ini dikategorikan sebagai
# GOOD FIT.
#
# MobileNetV2 menghasilkan testing accuracy lebih tinggi (98.96%) dibandingkan CNN From Scratch (97.26%). Model terbaik berdasarkan testing accuracy adalah
# MobileNetV2 Transfer Learning + Fine-Tuning. Confusion matrix dan classification report perlu digunakan
# untuk mengidentifikasi kelas yang paling mudah dan paling sulit dikenali serta
# untuk menilai precision, recall, dan F1-score setiap kelas.

# %% [markdown]
# # 16. Validasi File Ekspor dan Pembuatan ZIP

# %%
required_exports = {
    "SavedModel": SAVEDMODEL_DIR / "saved_model.pb",
    "TensorFlow Lite": TFLITE_PATH,
    "TensorFlow.js": TFJS_DIR / "model.json",
    "Keras": KERAS_PATH,
    "Class names": EXPORT_DIR / "class_names.json",
}

validation_records = []

for export_name, export_path in required_exports.items():
    exists = export_path.exists()
    validation_records.append({
        "format": export_name,
        "path": str(export_path),
        "tersedia": exists,
    })
    print(("✅" if exists else "❌"), export_name, "->", export_path)

export_validation_df = pd.DataFrame(validation_records)
display(export_validation_df)

if not export_validation_df["tersedia"].all():
    raise FileNotFoundError(
        "Ada format ekspor yang belum berhasil dibuat. "
        "Periksa output sel ekspor terkait."
    )

ZIP_BASE = Path("/content/databanana_submission")
ZIP_PATH = Path(shutil.make_archive(
    str(ZIP_BASE),
    "zip",
    root_dir=str(OUTPUT_DIR),
))

print("✅ Semua output dikompres:")
print(ZIP_PATH)
print(f"Ukuran ZIP: {ZIP_PATH.stat().st_size / (1024**2):.2f} MB")
# Out:
# ✅ SavedModel -> /content/databanana_outputs/exports/saved_model/saved_model.pb
# ✅ TensorFlow Lite -> /content/databanana_outputs/exports/best_datatrash_model.tflite
# ✅ TensorFlow.js -> /content/databanana_outputs/exports/tfjs_model/model.json
# ✅ Keras -> /content/databanana_outputs/exports/best_datatrash_model.keras
# ✅ Class names -> /content/databanana_outputs/exports/class_names.json
#             format                                               path  \
# 0       SavedModel  /content/databanana_outputs/exports/saved_mode...
# 1  TensorFlow Lite  /content/databanana_outputs/exports/best_datat...
# 2    TensorFlow.js  /content/databanana_outputs/exports/tfjs_model...
# 3            Keras  /content/databanana_outputs/exports/best_datat...
# 4      Class names  /content/databanana_outputs/exports/class_name...
#
#    tersedia
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# ✅ Semua output dikompres:
# /content/databanana_submission.zip
# Ukuran ZIP: 152.11 MB

# %%
# Download hasil ke komputer
from google.colab import files

files.download(str(ZIP_PATH))

# %% [markdown]
# ## Kesimpulan
#
# Notebook telah mencakup dua pendekatan model, callback, grafik akurasi dan loss, confusion matrix, classification report, analisis overfitting/underfitting/good fit, ekspor tiga format, serta inferensi menggunakan TensorFlow Lite.
#
# ### Catatan agar target 85% lebih mudah tercapai
#
# - Pastikan dataset benar-benar memiliki minimal 8.000 gambar dan minimal 4 kelas.
# - Periksa ketidakseimbangan kelas serta kualitas label.
# - Jalankan dengan GPU.
# - Naikkan `SCRATCH_EPOCHS`, `TL_STAGE1_EPOCHS`, atau `TL_FINETUNE_EPOCHS` jika kurva validasi masih membaik.
# - Kurangi augmentasi apabila objek menjadi terlalu sulit dikenali.
# - Tambah `FINE_TUNE_LAYERS` secara bertahap, misalnya dari 20 menjadi 30.
# - Jangan melakukan tuning berdasarkan testing set untuk menghindari data leakage.
